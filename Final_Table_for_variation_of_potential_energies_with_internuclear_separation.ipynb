# %%
#HCl Table Generating Code
# Table generating code for HCl
import numpy as np
import pandas as pd

Re_g = 1.274
Re_e = 1.55
k_g = 32.20
k_e = 26.21
shift = 8.6

R = np.linspace(0.8, 2.5, 30)

V_ground = 0.5 * k_g * (R - Re_g)**2
V_excited = 0.5 * k_e * (R - Re_e)**2 + shift

df = pd.DataFrame({
    "R (Å)": np.round(R, 3),
    "V_ground (eV)": np.round(V_ground, 4),
    "V_excited (eV)": np.round(V_excited, 4)
})

print("="*40)
print("Parabolic Table for HCl")
print(df.to_string(index=False))

df.to_csv("HCl_Harmonic_Table.csv", index=False)
# Out:
# ...
# Parabolic Table for HCl
#  R (Å)  V_ground (eV)  V_excited (eV)
#  0.800         3.6173         15.9716
#  0.859         2.7779         14.8643
#  0.917         2.0492         13.8470
#  0.976         1.4311         12.9199
#  1.034         0.9236         12.0828
#  1.093         0.5268         11.3357
#  1.152         0.2407         10.6788
#  1.210         0.0652         10.1119
#  1.269         0.0004          9.6350
#  1.328         0.0462          9.2483
#  1.386         0.2027          8.9516
#  1.445         0.4698          8.7450
#  1.503         0.8476          8.6284
#  1.562         1.3360          8.6019
#  1.621         1.9351          8.6655
#  1.679         2.6449          8.8191
#  1.738         3.4652          9.0628
#  1.797         4.3963          9.3966
#  1.855         5.4380          9.8205
#  1.914         6.5903         10.3344
#  1.972         7.8533         10.9384
#  2.031         9.2269         11.6324
#  2.090        10.7112         12.4165
# ...

# %%
# Table generating code for HF
import numpy as np
import pandas as pd

Re_g = 0.917
Re_e = 1.05
k_g = 60.29
k_e = 46.81
shift = 6.0

R = np.linspace(0.8, 2.5, 30)

V_ground = 0.5 * k_g * (R - Re_g)**2
V_excited = 0.5 * k_e * (R - Re_e)**2 + shift

df = pd.DataFrame({
    "R (Å)": np.round(R, 3),
    "V_ground (eV)": np.round(V_ground, 4),
    "V_excited (eV)": np.round(V_excited, 4)
})

print("="*40)
print("Parabolic Table for HF")
print(df.to_string(index=False))

df.to_csv("HF_Harmonic_Table.csv", index=False)
# Out:
# ...
# Parabolic Table for HF
#  R (Å)  V_ground (eV)  V_excited (eV)
#  0.800         0.4127          7.4628
#  0.859         0.1027          6.8572
#  0.917         0.0000          6.4125
#  0.976         0.1044          6.1286
#  1.034         0.4161          6.0056
#  1.093         0.9349          6.0435
#  1.152         1.6609          6.2422
#  1.210         2.5940          6.6018
#  1.269         3.7344          7.1222
#  1.328         5.0819          7.8035
#  1.386         6.6366          8.6456
#  1.445         8.3985          9.6486
#  1.503        10.3675         10.8124
#  1.562        12.5438         12.1371
#  1.621        14.9272         13.6227
#  1.679        17.5178         15.2691
#  1.738        20.3156         17.0764
#  1.797        23.3205         19.0445
#  1.855        26.5326         21.1735
#  1.914        29.9520         23.4634
#  1.972        33.5785         25.9141
#  2.031        37.4121         28.5256
#  2.090        41.4530         31.2981
# ...

# %%
# Table generating code for HBr
import numpy as np
import pandas as pd

Re_g = 1.414
Re_e = 1.60
k_g = 25.72
k_e = 20.60
shift = 5.3

R = np.linspace(0.8, 2.5, 30)

V_ground = 0.5 * k_g * (R - Re_g)**2
V_excited = 0.5 * k_e * (R - Re_e)**2 + shift

df = pd.DataFrame({
    "R (Å)": np.round(R, 3),
    "V_ground (eV)": np.round(V_ground, 4),
    "V_excited (eV)": np.round(V_excited, 4)
})

print("="*40)
print("Parabolic Table for HBr")
print(df.to_string(index=False))

df.to_csv("HBr_Harmonic_Table.csv", index=False)
# Out:
# ...
# Parabolic Table for HBr
#  R (Å)  V_ground (eV)  V_excited (eV)
#  0.800         4.8482         11.8920
#  0.859         3.9666         10.9613
#  0.917         3.1735         10.1014
#  0.976         2.4687          9.3123
#  1.034         1.8523          8.5940
#  1.093         1.3243          7.9465
#  1.152         0.8846          7.3698
#  1.210         0.5334          6.8639
#  1.269         0.2705          6.4287
#  1.328         0.0960          6.0644
#  1.386         0.0099          5.7708
#  1.445         0.0122          5.5480
#  1.503         0.1029          5.3960
#  1.562         0.2819          5.3148
#  1.621         0.5494          5.3044
#  1.679         0.9052          5.3648
#  1.738         1.3494          5.4960
#  1.797         1.8820          5.6979
#  1.855         2.5030          5.9707
#  1.914         3.2123          6.3142
#  1.972         4.0101          6.7285
#  2.031         4.8962          7.2136
#  2.090         5.8707          7.7696
# ...

# %%
# Table generating code for HI
import numpy as np
import pandas as pd

Re_g = 1.609
Re_e = 1.80
k_g = 19.60
k_e = 15.60
shift = 5.0

R = np.linspace(0.8, 2.5, 30)

V_ground = 0.5 * k_g * (R - Re_g)**2
V_excited = 0.5 * k_e * (R - Re_e)**2 + shift

df = pd.DataFrame({
    "R (Å)": np.round(R, 3),
    "V_ground (eV)": np.round(V_ground, 4),
    "V_excited (eV)": np.round(V_excited, 4)
})

print("="*40)
print("Parabolic Table for HI")
print(df.to_string(index=False))

df.to_csv("HI_Harmonic_Table.csv", index=False)
# Out:
# ...
# Parabolic Table for HI
#  R (Å)  V_ground (eV)  V_excited (eV)
#  0.800         6.4139         12.8000
#  0.859         5.5181         11.9123
#  0.917         4.6896         11.0782
#  0.976         3.9285         10.2978
#  1.034         3.2347          9.5709
#  1.093         2.6083          8.8977
#  1.152         2.0492          8.2780
#  1.210         1.5575          7.7120
#  1.269         1.1331          7.1996
#  1.328         0.7761          6.7408
#  1.386         0.4864          6.3356
#  1.445         0.2641          5.9840
#  1.503         0.1092          5.6860
#  1.562         0.0216          5.4416
#  1.621         0.0013          5.2508
#  1.679         0.0484          5.1136
#  1.738         0.1629          5.0300
#  1.797         0.3447          5.0001
#  1.855         0.5939          5.0237
#  1.914         0.9104          5.1010
#  1.972         1.2943          5.2319
#  2.031         1.7455          5.4163
#  2.090         2.2641          5.6544
# ...

# %%
# Table generating code for CO
import numpy as np
import pandas as pd

Re_g = 1.128
Re_e = 1.22
k_g = 116.09
k_e = 84.26
shift = 8.2

R = np.linspace(0.8, 2.5, 30)

V_ground = 0.5 * k_g * (R - Re_g)**2
V_excited = 0.5 * k_e * (R - Re_e)**2 + shift

df = pd.DataFrame({
    "R (Å)": np.round(R, 3),
    "V_ground (eV)": np.round(V_ground, 4),
    "V_excited (eV)": np.round(V_excited, 4)
})

print("="*40)
print("Parabolic Table for CO")
print(df.to_string(index=False))

df.to_csv("CO_Harmonic_Table.csv", index=False)
# Out:
# ...
# Parabolic Table for CO
#  R (Å)  V_ground (eV)  V_excited (eV)
#  0.800         6.2447         15.6317
#  0.859         4.2120         13.7020
#  0.917         2.5783         12.0618
#  0.976         1.3435         10.7111
#  1.034         0.5076          9.6500
#  1.093         0.0707          8.8784
#  1.152         0.0327          8.3964
#  1.210         0.3936          8.2039
#  1.269         1.1534          8.3010
#  1.328         2.3122          8.6876
#  1.386         3.8699          9.3638
#  1.445         5.8265         10.3296
#  1.503         8.1821         11.5848
#  1.562        10.9366         13.1297
#  1.621        14.0900         14.9641
#  1.679        17.6424         17.0880
#  1.738        21.5937         19.5015
#  1.797        25.9439         22.2045
#  1.855        30.6930         25.1971
#  1.914        35.8411         28.4792
#  1.972        41.3881         32.0509
#  2.031        47.3340         35.9121
#  2.090        53.6789         40.0629
# ...

# %%
# Table generating code for NO
import numpy as np
import pandas as pd

Re_g = 1.150
Re_e = 1.29
k_g = 99.24
k_e = 71.78
shift = 6.1

R = np.linspace(0.8, 2.5, 30)

V_ground = 0.5 * k_g * (R - Re_g)**2
V_excited = 0.5 * k_e * (R - Re_e)**2 + shift

df = pd.DataFrame({
    "R (Å)": np.round(R, 3),
    "V_ground (eV)": np.round(V_ground, 4),
    "V_excited (eV)": np.round(V_excited, 4)
})

print("="*40)
print("Parabolic Table for NO")
print(df.to_string(index=False))

df.to_csv("NO_Harmonic_Table.csv", index=False)
# Out:
# ...
# Parabolic Table for NO
#  R (Å)  V_ground (eV)  V_excited (eV)
#  0.800         6.0784         14.7172
#  0.859         4.2128         12.7787
#  0.917         2.6882         11.0869
#  0.976         1.5047          9.6417
#  1.034         0.6621          8.4432
#  1.093         0.1606          7.4914
#  1.152         0.0001          6.7862
#  1.210         0.1807          6.3277
#  1.269         0.7023          6.1159
#  1.328         1.5649          6.1507
#  1.386         2.7685          6.4322
#  1.445         4.3131          6.9603
#  1.503         6.1988          7.7352
#  1.562         8.4255          8.7566
#  1.621        10.9932         10.0248
#  1.679        13.9020         11.5396
#  1.738        17.1518         13.3010
#  1.797        20.7426         15.3092
#  1.855        24.6744         17.5640
#  1.914        28.9473         20.0654
#  1.972        33.5612         22.8136
#  2.031        38.5161         25.8084
#  2.090        43.8121         29.0498
# ...

# %%
# Table generating code for O2
import numpy as np
import pandas as pd

Re_g = 1.207
Re_e = 1.31
k_g = 73.445
k_e = 53.05
shift = 6.2

R = np.linspace(0.8, 2.5, 30)

V_ground = 0.5 * k_g * (R - Re_g)**2
V_excited = 0.5 * k_e * (R - Re_e)**2 + shift

df = pd.DataFrame({
    "R (Å)": np.round(R, 3),
    "V_ground (eV)": np.round(V_ground, 4),
    "V_excited (eV)": np.round(V_excited, 4)
})

print("="*40)
print("Parabolic Table for O2")
print(df.to_string(index=False))

df.to_csv("O2_Harmonic_Table.csv", index=False)
# Out:
# ...
# Parabolic Table for O2
#  R (Å)  V_ground (eV)  V_excited (eV)
#  0.800         6.0830         13.0992
#  0.859         4.4569         11.6043
#  0.917         3.0832         10.2917
#  0.976         1.9619          9.1615
#  1.034         1.0929          8.2135
#  1.093         0.4764          7.4478
#  1.152         0.1122          6.8645
#  1.210         0.0004          6.4634
#  1.269         0.1410          6.2447
#  1.328         0.5340          6.2082
#  1.386         1.1793          6.3540
#  1.445         2.0771          6.6822
#  1.503         3.2272          7.1926
#  1.562         4.6298          7.8854
#  1.621         6.2847          8.7604
#  1.679         8.1919          9.8177
#  1.738        10.3516         11.0574
#  1.797        12.7637         12.4793
#  1.855        15.4281         14.0836
#  1.914        18.3450         15.8701
#  1.972        21.5142         17.8390
#  2.031        24.9358         19.9901
#  2.090        28.6098         22.3235
# ...

# %%
# Table generating code for N2
import numpy as np
import pandas as pd

Re_g = 1.098
Re_e = 1.17
k_g = 143.337
k_e = 99.86
shift = 7.4

R = np.linspace(0.8, 2.5, 30)

V_ground = 0.5 * k_g * (R - Re_g)**2
V_excited = 0.5 * k_e * (R - Re_e)**2 + shift

df = pd.DataFrame({
    "R (Å)": np.round(R, 3),
    "V_ground (eV)": np.round(V_ground, 4),
    "V_excited (eV)": np.round(V_excited, 4)
})

print("="*40)
print("Parabolic Table for N2")
print(df.to_string(index=False))

df.to_csv("N2_Harmonic_Table.csv", index=False)
# Out:
# ...
# Parabolic Table for N2
#  R (Å)  V_ground (eV)  V_excited (eV)
#  0.800         6.3644         11.9135
#  0.859         4.1068         10.5966
#  0.917         2.3417          9.5063
#  0.976         1.0691          8.6426
#  1.034         0.2891          8.0055
#  1.093         0.0017          7.5950
#  1.152         0.2069          7.4110
#  1.210         0.9046          7.4537
#  1.269         2.0948          7.7229
#  1.328         3.7776          8.2187
#  1.386         5.9530          8.9412
#  1.445         8.6210          9.8902
#  1.503        11.7815         11.0658
#  1.562        15.4345         12.4680
#  1.621        19.5802         14.0968
#  1.679        24.2183         15.9522
#  1.738        29.3491         18.0342
#  1.797        34.9724         20.3427
#  1.855        41.0883         22.8779
#  1.914        47.6967         25.6397
#  1.972        54.7977         28.6280
#  2.031        62.3913         31.8429
#  2.090        70.4774         35.2845
# ...

# %%
# Table generating code for Br2
import numpy as np
import pandas as pd

Re_g = 2.281
Re_e = 2.55
k_g = 15.330
k_e = 11.86
shift = 2.7

R = np.linspace(0.8, 2.5, 30)

V_ground = 0.5 * k_g * (R - Re_g)**2
V_excited = 0.5 * k_e * (R - Re_e)**2 + shift

df = pd.DataFrame({
    "R (Å)": np.round(R, 3),
    "V_ground (eV)": np.round(V_ground, 4),
    "V_excited (eV)": np.round(V_excited, 4)
})

print("="*40)
print("Parabolic Table for Br2")
print(df.to_string(index=False))

df.to_csv("Br2_Harmonic_Table.csv", index=False)
# Out:
# ...
# Parabolic Table for Br2
#  R (Å)  V_ground (eV)  V_excited (eV)
#  0.800        16.8121         20.8606
#  0.859        15.5075         19.6643
#  0.917        14.2557         18.5088
#  0.976        13.0564         17.3940
#  1.034        11.9099         16.3200
#  1.093        10.8161         15.2867
#  1.152         9.7749         14.2942
#  1.210         8.7864         13.3424
#  1.269         7.8506         12.4314
#  1.328         6.9675         11.5612
#  1.386         6.1370         10.7317
#  1.445         5.3592          9.9429
#  1.503         4.6342          9.1950
#  1.562         3.9617          8.4877
#  1.621         3.3420          7.8213
#  1.679         2.7750          7.1955
#  1.738         2.2606          6.6106
#  1.797         1.7989          6.0664
#  1.855         1.3899          5.5629
#  1.914         1.0336          5.1002
#  1.972         0.7299          4.6783
#  2.031         0.4789          4.2971
#  2.090         0.2806          3.9567
# ...

# %%
# Table generating code for Cl2
import numpy as np
import pandas as pd

Re_g = 1.987
Re_e = 2.20
k_g = 20.10
k_e = 15.60
shift = 3.6

R = np.linspace(0.8, 2.5, 30)

V_ground = 0.5 * k_g * (R - Re_g)**2
V_excited = 0.5 * k_e * (R - Re_e)**2 + shift

df = pd.DataFrame({
    "R (Å)": np.round(R, 3),
    "V_ground (eV)": np.round(V_ground, 4),
    "V_excited (eV)": np.round(V_excited, 4)
})

print("="*40)
print("Parabolic Table for Cl2")
print(df.to_string(index=False))

df.to_csv("Cl2_Harmonic_Table.csv", index=False)
# Out:
# ...
# Parabolic Table for Cl2
#  R (Å)  V_ground (eV)  V_excited (eV)
#  0.800        14.1601         18.8880
#  0.859        12.7961         17.6345
#  0.917        11.5011         16.4347
#  0.976        10.2751         15.2884
#  1.034         9.1183         14.1958
#  1.093         8.0305         13.1567
#  1.152         7.0117         12.1713
#  1.210         6.0621         11.2395
#  1.269         5.1815         10.3612
#  1.328         4.3700          9.5366
#  1.386         3.6276          8.7656
#  1.445         2.9542          8.0482
#  1.503         2.3499          7.3844
#  1.562         1.8147          6.7743
#  1.621         1.3485          6.2177
#  1.679         0.9515          5.7147
#  1.738         0.6235          5.2654
#  1.797         0.3645          4.8696
#  1.855         0.1747          4.5275
#  1.914         0.0539          4.2389
#  1.972         0.0021          4.0040
#  2.031         0.0195          3.8227
#  2.090         0.1059          3.6950
# ...
